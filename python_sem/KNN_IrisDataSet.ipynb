# %%
 # Load the Iris dataset from the scikit-learn library and perform classification on it with the k-nearest
 # neighbors algorithm. Use a KNeighborsClassifier with the default k value. What is the prediction
 # accuracy?

# %%
# 🧠 What is the Iris dataset?
# The Iris dataset is one of the most famous datasets in machine learning and statistics. It was introduced by the British biologist Ronald Fisher in 1936.

# It contains 150 flower samples from 3 species of Iris flowers:

# Iris Setosa

# Iris Versicolor

# Iris Virginica

# For each flower sample, we are given 4 features (measurements):

# Sepal length (in cm)

# Sepal width (in cm)

# Petal length (in cm)

# Petal width (in cm)

# The goal is to predict the species of the flower based on these 4 features.

# %%
#  What is the goal of this problem?
# You're asked to:

# Load the Iris dataset.

# Use the K-Nearest Neighbors (KNN) algorithm for classification.

# Train the model and then test it on new data.

# Measure how accurate the model is at predicting the correct flower species.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score


# load_iris: load the iris dataset


iris=load_iris()
x=iris.data
y=iris.target

# iris.data is 2D like row and columns
# each row represent one flower sample
# each column represent a feature(the mesurement of the flower)
# sepel length
# sepel width
# petal width
# petal length

# iris.target acutual data that contain the actual flower type

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
iris.target.shape
# Out:
# (150,)

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=42)

# %%
# train your data
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

accuracy=accuracy_score(y_test,y_pred)

# %%
print(f'Prediction accuray:{accuracy:.2f}')
print(f'Prediction accuray:{y_pred}')
# Out:
# Prediction accuray:1.00
# Prediction accuray:[1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0]

# %%
# Dimensionality reduction
original data has 4 dim. we reduce to 2D to plot in a graph
using the technique/method called t-SNE(t-distributed Stochastic Neighbor Embedding)
# Out:
#   Cell In[16], line 2
#     original data has 4 dim. we reduce to 2D to plot in a graph
#                                           ^
# SyntaxError: invalid decimal literal

# %%
tsne=TSNE(n_components=2,random_state=42)
X_tsne=tsne.fit_transform(x)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y, palette="deep")
plt.title("t-SNE Visualization of Iris Dataset")
plt.xlabel("TSNE Component 1")
plt.ylabel("TSNE Component 2")
plt.legend(title="Species", labels=iris.target_names)
plt.grid(True)
plt.show()

# %% [markdown]
# '''
# Perfect! Let’s now go through the **plotting part of the t-SNE code**, **word by word**, and explain **what it does**, **why it’s used**, and **how it works** — in a super beginner-friendly way. 🎨✨
#
# ---
#
# ## 🔢 The Code:
# ```python
# plt.figure(figsize=(8, 6))
# sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y, palette="deep")
# plt.title("t-SNE Visualization of Iris Dataset")
# plt.xlabel("TSNE Component 1")
# plt.ylabel("TSNE Component 2")
# plt.legend(title="Species", labels=iris.target_names)
# plt.grid(True)
# plt.show()
# ```
#
# ---
#
# ### 🔹 Line 1:
# ```python
# plt.figure(figsize=(8, 6))
# ```
#
# #### ✅ What:
# - This creates a **new figure (canvas)** for plotting.
#
# #### ✅ Why:
# - We need a "blank page" to draw our scatterplot on.
# - `figsize=(8, 6)` sets the **width to 8 inches** and **height to 6 inches**.
#
# #### ✅ How:
# - It uses **Matplotlib's** `pyplot` interface (`plt`) to prepare the space for drawing.
#
# ---
#
# ### 🔹 Line 2:
# ```python
# sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y, palette="deep")
# ```
#
# #### ✅ What:
# - This draws the **scatterplot** using **Seaborn** (a high-level wrapper over Matplotlib).
# - `x=X_tsne[:, 0]`: use the first t-SNE component (first column) for the x-axis.
# - `y=X_tsne[:, 1]`: use the second t-SNE component (second column) for the y-axis.
# - `hue=y`: color each point based on its actual class label (species).
# - `palette="deep"`: uses a nice-looking, distinct color scheme.
#
# #### ✅ Why:
# - We're plotting the reduced 2D data from t-SNE to **visualize how the data is grouped**.
# - Using `hue=y` lets us **see which flower species** each point belongs to.
#
# #### ✅ How:
# - Seaborn automatically handles coloring, legends, and styling.
#
# ---
#
# ### 🔹 Line 3:
# ```python
# plt.title("t-SNE Visualization of Iris Dataset")
# ```
#
# #### ✅ What:
# - Adds a **title** to the plot.
#
# #### ✅ Why:
# - To make the graph understandable to someone viewing it — they’ll know it’s a t-SNE plot of the Iris dataset.
#
# ---
#
# ### 🔹 Line 4:
# ```python
# plt.xlabel("TSNE Component 1")
# ```
#
# #### ✅ What:
# - Labels the **x-axis** as “TSNE Component 1”.
#
# #### ✅ Why:
# - t-SNE reduced the original 4 features down to 2. This is the **first new feature** (x-axis) from t-SNE.
# - Helps viewers understand what this axis represents.
#
# ---
#
# ### 🔹 Line 5:
# ```python
# plt.ylabel("TSNE Component 2")
# ```
#
# #### ✅ What:
# - Labels the **y-axis** as “TSNE Component 2”.
#
# #### ✅ Why:
# - This is the **second new feature** (y-axis) from t-SNE.
# - Now both axes are labeled, which is good practice for all plots.
#
# ---
#
# ### 🔹 Line 6:
# ```python
# plt.legend(title="Species", labels=iris.target_names)
# ```
#
# #### ✅ What:
# - Adds a **legend box** to the plot.
# - `title="Species"`: sets the title of the legend.
# - `labels=iris.target_names`: uses the actual flower names: `['setosa', 'versicolor', 'virginica']`.
#
# #### ✅ Why:
# - Helps the viewer match the **colors to species names**.
# - Makes the plot **interpretable**.
#
# ---
#
# ### 🔹 Line 7:
# ```python
# plt.grid(True)
# ```
#
# #### ✅ What:
# - Turns on the **grid lines** on the plot.
#
# #### ✅ Why:
# - Helps you **visually align points** and improves readability.
#
# ---
#
# ### 🔹 Line 8:
# ```python
# plt.show()
# ```
#
# #### ✅ What:
# - **Displays** the plot on the screen.
#
# #### ✅ Why:
# - Without this line (in scripts or some notebooks), the plot might not appear.
# - It's the final command to **"render" the plot**.
#
# ---
#
# ## ✅ Summary
#
# This entire block of code takes the **2D t-SNE data**, and:
# 1. Creates a nicely-sized canvas 📐
# 2. Plots the points with color-coded species 🎨
# 3. Adds helpful labels and a legend 🏷️
# 4. Displays the result 📊
#
# You now have a **visual snapshot** of how your flowers are grouped based on their measurements. It’s a powerful way to **explore data before modeling**.
#
# Let me know if you want to animate this or compare with PCA side-by-side!Perfect! Let’s now go through the **plotting part of the t-SNE code**, **word by word**, and explain **what it does**, **why it’s used**, and **how it works** — in a super beginner-friendly way. 🎨✨
#
# ---
#
# ## 🔢 The Code:
# ```python
# plt.figure(figsize=(8, 6))
# sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y, palette="deep")
# plt.title("t-SNE Visualization of Iris Dataset")
# plt.xlabel("TSNE Component 1")
# plt.ylabel("TSNE Component 2")
# plt.legend(title="Species", labels=iris.target_names)
# plt.grid(True)
# plt.show()
# ```
#
# ---
#
# ### 🔹 Line 1:
# ```python
# plt.figure(figsize=(8, 6))
# ```
#
# #### ✅ What:
# - This creates a **new figure (canvas)** for plotting.
#
# #### ✅ Why:
# - We need a "blank page" to draw our scatterplot on.
# - `figsize=(8, 6)` sets the **width to 8 inches** and **height to 6 inches**.
#
# #### ✅ How:
# - It uses **Matplotlib's** `pyplot` interface (`plt`) to prepare the space for drawing.
#
# ---
#
# ### 🔹 Line 2:
# ```python
# sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=y, palette="deep")
# ```
#
# #### ✅ What:
# - This draws the **scatterplot** using **Seaborn** (a high-level wrapper over Matplotlib).
# - `x=X_tsne[:, 0]`: use the first t-SNE component (first column) for the x-axis.
# - `y=X_tsne[:, 1]`: use the second t-SNE component (second column) for the y-axis.
# - `hue=y`: color each point based on its actual class label (species).
# - `palette="deep"`: uses a nice-looking, distinct color scheme.
#
# #### ✅ Why:
# - We're plotting the reduced 2D data from t-SNE to **visualize how the data is grouped**.
# - Using `hue=y` lets us **see which flower species** each point belongs to.
#
# #### ✅ How:
# - Seaborn automatically handles coloring, legends, and styling.
#
# ---
#
# ### 🔹 Line 3:
# ```python
# plt.title("t-SNE Visualization of Iris Dataset")
# ```
#
# #### ✅ What:
# - Adds a **title** to the plot.
#
# #### ✅ Why:
# - To make the graph understandable to someone viewing it — they’ll know it’s a t-SNE plot of the Iris dataset.
#
# ---
#
# ### 🔹 Line 4:
# ```python
# plt.xlabel("TSNE Component 1")
# ```
#
# #### ✅ What:
# - Labels the **x-axis** as “TSNE Component 1”.
#
# #### ✅ Why:
# - t-SNE reduced the original 4 features down to 2. This is the **first new feature** (x-axis) from t-SNE.
# - Helps viewers understand what this axis represents.
#
# ---
#
# ### 🔹 Line 5:
# ```python
# plt.ylabel("TSNE Component 2")
# ```
#
# #### ✅ What:
# - Labels the **y-axis** as “TSNE Component 2”.
#
# #### ✅ Why:
# - This is the **second new feature** (y-axis) from t-SNE.
# - Now both axes are labeled, which is good practice for all plots.
#
# ---
#
# ### 🔹 Line 6:
# ```python
# plt.legend(title="Species", labels=iris.target_names)
# ```
#
# #### ✅ What:
# - Adds a **legend box** to the plot.
# - `title="Species"`: sets the title of the legend.
# - `labels=iris.target_names`: uses the actual flower names: `['setosa', 'versicolor', 'virginica']`.
#
# #### ✅ Why:
# - Helps the viewer match the **colors to species names**.
# - Makes the plot **interpretable**.
#
# ---
#
# ### 🔹 Line 7:
# ```python
# plt.grid(True)
# ```
#
# #### ✅ What:
# - Turns on the **grid lines** on the plot.
#
# #### ✅ Why:
# - Helps you **visually align points** and improves readability.
#
# ---
#
# ### 🔹 Line 8:
# ```python
# plt.show()
# ```
#
# #### ✅ What:
# - **Displays** the plot on the screen.
#
# #### ✅ Why:
# - Without this line (in scripts or some notebooks), the plot might not appear.
# - It's the final command to **"render" the plot**.
#
# ---
#
# ## ✅ Summary
#
# This entire block of code takes the **2D t-SNE data**, and:
# 1. Creates a nicely-sized canvas 📐
# 2. Plots the points with color-coded species 🎨
# 3. Adds helpful labels and a legend 🏷️
# 4. Displays the result 📊
#
# You now have a **visual snapshot** of how your flowers are grouped based on their measurements. It’s a powerful way to **explore data before modeling**.
#
# Let me know if you want to animate this or compare with PCA side-by-side!
# '''

# %% [markdown]
# from sklearn.datasets import load_iris
# from sklearn.model_selection import KFold, cross_val_score
# from sklearn.neighbors import KNeighborsClassifier
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Step 1: Load the dataset
# iris = load_iris()
# X = iris.data
# y = iris.target
#
# # Step 2: Setup KFold cross-validation
# kf = KFold(n_splits=5, shuffle=True, random_state=42)
#
# # Step 3: Try different k values
# k_values = range(1, 31)
# mean_scores = []
#
# for k in k_values:
#     knn = KNeighborsClassifier(n_neighbors=k)
#     scores = cross_val_score(knn, X, y, cv=kf)
#     mean_scores.append(scores.mean())
#
# # Step 4: Find the best k
# optimal_k = k_values[np.argmax(mean_scores)]
# print(f"Optimal k: {optimal_k}")
# print(f"Best cross-validated accuracy: {max(mean_scores):.2f}")
#
# # Step 5: Plot accuracy vs k
# plt.figure(figsize=(10, 6))
# plt.plot(k_values, mean_scores, marker='o')
# plt.title('KNN Accuracy vs k (number of neighbors)')
# plt.xlabel('k')
# plt.ylabel('Cross-Validated Accuracy')
# plt.grid(True)
# plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the dataset
iris = load_iris()
X = iris.data
y = iris.target

# Step 2: Setup KFold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Step 3: Try different k values
k_values = range(1, 31)
mean_scores = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=kf)
    mean_scores.append(scores.mean())

# Step 4: Find the best k
optimal_k = k_values[np.argmax(mean_scores)]
print(f"Optimal k: {optimal_k}")
print(f"Best cross-validated accuracy: {max(mean_scores):.2f}")

# Step 5: Plot accuracy vs k
plt.figure(figsize=(10, 6))
plt.plot(k_values, mean_scores, marker='o')
plt.title('KNN Accuracy vs k (number of neighbors)')
plt.xlabel('k')
plt.ylabel('Cross-Validated Accuracy')
plt.grid(True)
plt.show()
# Out:
# Optimal k: 13
# Best cross-validated accuracy: 0.98
